# %%
import pandas as pd
redwine=pd.read_csv('winequality-red.csv',sep=";") #seperated information mentioned to get it show into right formate
redwine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
redwine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
#Lets chcek the target variable value counts
redwine["quality"].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
redwine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
redwine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
x=redwine.drop(columns=["quality"])
y=redwine[["quality"]]

# %%
#scaling the input variable
#Linearregression algorithm requires all features to be on common scale
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#lets make a function which evaluates the model using cross_val_score
from sklearn.model_selection import cross_val_score
def model_evaluation(model,x,y):
    c_scores=cross_val_score(model,x,y,cv=5,scoring="r2")
    print("Mean r2 score for regressor: ",c_scores.mean())
    print("standard deviation in r2 score for regressor: ",c_scores.std())
    print(c_scores)

# %%
#lets make use of KNN regressor
#we will use pipeline to bring bring features to common scale
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
knr=KNeighborsRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor())])
parameters = {"knr__n_neighbors":range(2,30)}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(x, y)
clf.best_params_
# Out:
# {'knr__n_neighbors': 29}

# %%
pipeline_knr=Pipeline([("ss",StandardScaler()),("knr",KNeighborsRegressor(n_neighbors=29))])
#knr=KNeighborsRegressor(n_neighbors=29)
maxr2_score(pipeline_knr,x,y)
# Out:
# r2 score corresponding to  42  is  0.3623867312637836
# r2 score corresponding to  43  is  0.325865472308695
# r2 score corresponding to  44  is  0.3287804535557596
# r2 score corresponding to  45  is  0.34996987464718754
# r2 score corresponding to  46  is  0.3127699846007115
# r2 score corresponding to  47  is  0.3588464796854719
# r2 score corresponding to  48  is  0.297974613552205
# r2 score corresponding to  49  is  0.30847621817871107
# r2 score corresponding to  50  is  0.30722273035455927
# r2 score corresponding to  51  is  0.2746587132928632
# r2 score corresponding to  52  is  0.31789224493856283
# r2 score corresponding to  53  is  0.3794818462682543
# r2 score corresponding to  54  is  0.34600497795161855
# r2 score corresponding to  55  is  0.3720434176847447
# r2 score corresponding to  56  is  0.3627865021116077
# r2 score corresponding to  57  is  0.31185218469342857
# r2 score corresponding to  58  is  0.3678533683043572
# r2 score corresponding to  59  is  0.2745639201911224
# r2 score corresponding to  60  is  0.3671893321922739
# r2 score corresponding to  61  is  0.3897112474327099
# r2 score corresponding to  62  is  0.3482934475887459
# r2 score corresponding to  63  is  0.35169248102296635
# r2 score corresponding to  64  is  0.25516044198777865
# r2 score corresponding to  65  is  0.32748901129209385
# r2 score corresponding to  66  is  0.2601291246391123
# r2 score corresponding to  67  is  0.3221577770345806
# r2 score corresponding to  68  is  0.3320963328265204
# r2 score corresponding to  69  is  0.34363787522740474
# r2 score corresponding to  70  is  0.3803810163131649
# r2 score corresponding to  71  is  0.3605239789596977
# r2 score corresponding to  72  is  0.28433943345771606
# r2 score corresponding to  73  is  0.2864373302359341
# r2 score corresponding to  74  is  0.31236031873825276
# r2 score corresponding to  75  is  0.3066682985711585
# r2 score corresponding to  76  is  0.3155875306303464
# r2 score corresponding to  77  is  0.3152184552648962
# r2 score corresponding to  78  is  0.3358836138765424
# r2 score corresponding to  79  is  0.3384002985952145
# r2 score corresponding to  80  is  0.26992448247678424
# r2 score corresponding to  81  is  0.3280191584122324
# r2 score corresponding to  82  is  0.33757435646691536
# r2 score corresponding to  83  is  0.36186561873788514
# r2 score corresponding to  84  is  0.3224091067518551
# r2 score corresponding to  85  is  0.32970138531218984
# r2 score corresponding to  86  is  0.3653788134239623
# r2 score corresponding to  87  is  0.19405167905593512
# r2 score corresponding to  88  is  0.25895255759982794
# r2 score corresponding to  89  is  0.38291740763147475
# r2 score corresponding to  90  is  0.3301770253074712
# r2 score corresponding to  91  is  0.3688536324769742
# r2 score corresponding to  92  is  0.3485818402191899
# r2 score corresponding to  93  is  0.3847390739570715
# r2 score corresponding to  94  is  0.2716492700529969
# r2 score corresponding to  95  is  0.3026548497145698
# r2 score corresponding to  96  is  0.3137275233199973
# r2 score corresponding to  97  is  0.30364225866843053
# r2 score corresponding to  98  is  0.29778742150277193
# r2 score corresponding to  99  is  0.31027333503392607
# max r2 score corresponding to  61  is  0.3897112474327099
# 61

# %%
#Lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
pipeline=Pipeline([("ss",StandardScaler()),("rfr",RandomForestRegressor())])
parameters = {"rfr__n_estimators":[10,100,500]}
clf = GridSearchCV(pipeline, parameters, cv=5,scoring="r2")
clf.fit(x,y)
clf.best_params_
# Out:
# {'rfr__n_estimators': 500}

# %%
pipeline_rfr=Pipeline([("ss",StandardScaler()),("rfr",RandomForestRegressor(n_estimators=500))])
maxr2_score(pipeline_rfr,x,y)
# Out:
# r2 score corresponding to  42  is  0.5259479765089138
# r2 score corresponding to  43  is  0.4756114651972728
# r2 score corresponding to  44  is  0.42858685752628056
# r2 score corresponding to  45  is  0.4736357657071931
# r2 score corresponding to  46  is  0.48489682331551986
# r2 score corresponding to  47  is  0.4873781809975174
# r2 score corresponding to  48  is  0.46541125919260784
# r2 score corresponding to  49  is  0.5018853769554412
# r2 score corresponding to  50  is  0.4655165199270642
# r2 score corresponding to  51  is  0.3880133493628276
# r2 score corresponding to  52  is  0.493134530463777
# r2 score corresponding to  53  is  0.5119715703992997
# r2 score corresponding to  54  is  0.49991807654563303
# r2 score corresponding to  55  is  0.48153758717314754
# r2 score corresponding to  56  is  0.49386821674876846
# r2 score corresponding to  57  is  0.43401737478923585
# r2 score corresponding to  58  is  0.5135605316860044
# r2 score corresponding to  59  is  0.4535734148827727
# r2 score corresponding to  60  is  0.506084705882353
# r2 score corresponding to  61  is  0.5774338825757576
# r2 score corresponding to  62  is  0.5106544955925565
# r2 score corresponding to  63  is  0.48419887718699794
# r2 score corresponding to  64  is  0.46777258310288394
# r2 score corresponding to  65  is  0.542964921855619
# r2 score corresponding to  66  is  0.444224513881714
# r2 score corresponding to  67  is  0.5410058050685501
# r2 score corresponding to  68  is  0.4772181632433925
# r2 score corresponding to  69  is  0.5153856293156491
# r2 score corresponding to  70  is  0.5024701498084971
# r2 score corresponding to  71  is  0.524572080266522
# r2 score corresponding to  72  is  0.4861164191195505
# r2 score corresponding to  73  is  0.4418897054737916
# r2 score corresponding to  74  is  0.5077968725325589
# r2 score corresponding to  75  is  0.3820546791674978
# r2 score corresponding to  76  is  0.46091910536275726
# r2 score corresponding to  77  is  0.4777455271467862
# r2 score corresponding to  78  is  0.5189461922529524
# r2 score corresponding to  79  is  0.4628921417073325
# r2 score corresponding to  80  is  0.4131185979476537
# r2 score corresponding to  81  is  0.48767526797813876
# r2 score corresponding to  82  is  0.44623582693761965
# r2 score corresponding to  83  is  0.5701752083363867
# r2 score corresponding to  84  is  0.4650989486133287
# r2 score corresponding to  85  is  0.440725735754146
# r2 score corresponding to  86  is  0.5210157014925373
# r2 score corresponding to  87  is  0.37464415970287845
# r2 score corresponding to  88  is  0.434153710331068
# r2 score corresponding to  89  is  0.4911977320162956
# r2 score corresponding to  90  is  0.47734219316258975
# r2 score corresponding to  91  is  0.4888288624833469
# r2 score corresponding to  92  is  0.5475336449689484
# r2 score corresponding to  93  is  0.5407651603103454
# r2 score corresponding to  94  is  0.45318846326276463
# r2 score corresponding to  95  is  0.436762716352047
# r2 score corresponding to  96  is  0.4570096489241223
# r2 score corresponding to  97  is  0.48244751037908173
# r2 score corresponding to  98  is  0.43066196724605643
# r2 score corresponding to  99  is  0.46800744027804264
# max r2 score corresponding to  61  is  0.5774338825757576
# 61

# %%
#lets chcek the cross_val_score for random forest
print("RANDOM FOREST\n\n")
model_evaluation(pipeline_rfr,x,y)
# Out:
# RANDOM FOREST
#
#
# Mean r2 score for regressor:  0.3181888239130997
# standard deviation in r2 score for regressor:  0.04348681227784965
# [0.26220648 0.35983363 0.36940288 0.32509206 0.27440907]

# %%
#lets make the final model and save it
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 61,test_size=0.20)
pipeline_rfr.fit(x_train,y_train)
y_pred = pipeline_rfr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics for random forest model
print("MSE is: ",mean_squared_error(y_test,y_pred))
print("r2_score is: ",r2_score(y_test,y_pred))
# Out:
# MSE is:  0.2768334875000001
# r2_score is:  0.5805553219696968
